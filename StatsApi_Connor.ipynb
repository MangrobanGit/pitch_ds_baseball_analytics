# %%
! pip install MLB-StatsAPI
# Out:
# Collecting MLB-StatsAPI
#   Using cached https://files.pythonhosted.org/packages/0a/a1/161c26b5bde99294d444335ec293adb3a13b0329bd5c391bc069c1b6e81d/MLB_StatsAPI-0.0.8-py3-none-any.whl
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.7/site-packages (from MLB-StatsAPI) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.7/site-packages (from requests->MLB-StatsAPI) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.7/site-packages (from requests->MLB-StatsAPI) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Applications/anaconda3/lib/python3.7/site-packages (from requests->MLB-StatsAPI) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Applications/anaconda3/lib/python3.7/site-packages (from requests->MLB-StatsAPI) (2.8)
# Installing collected packages: MLB-StatsAPI
# Successfully installed MLB-StatsAPI-0.0.8

# %%
import statsapi
from statsapi import ENDPOINTS
import pandas as pd

# %%
# Create List of Games

# %%
game_test = statsapi.get('game_playByPlay',{"gamePk":566000})
game_test
# Out:
# {'copyright': 'Copyright 2019 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'allPlays': [{'result': {'type': 'atBat',
#     'event': 'Pop Out',
#     'eventType': 'field_out',
#     'description': 'Lorenzo Cain pops out to first baseman Pete Alonso in foul territory.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 0,
#     'halfInning': 'top',
#     'inning': 1,
#     'startTime': '2019-04-28T16:12:30.000Z',
#     'endTime': '2019-04-28T17:11:43.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 0, 'strikes': 0, 'outs': 1},
#    'matchup': {'batter': {'id': 456715,
#      'fullName': 'Lorenzo Cain',
#      'link': '/api/v1/people/456715'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 571927,
#      'fullName': 'Steven Matz',
#      'link': '/api/v1/people/571927'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 1},
#      'details': {'event': 'Field Out',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 456715,
#        'fullName': 'Lorenzo Cain',
#        'link': '/api/v1/people/456715'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 0},
#      'credits': [{'player': {'id': 624413, 'link': '/api/v1/people/624413'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'X',
#        'description': 'Hit Into Play - Out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 0},
#      'pitchData': {'startSpeed': 93.1,
#       'endSpeed': 85.0,
#       'strikeZoneTop': 3.68,
#       'strikeZoneBottom': 1.75,
#       'coordinates': {'aY': 29.29,
#        'aZ': -15.55,
#        'pfxX': 9.17,
#        'pfxZ': 9.01,
#        'pX': -0.49,
#        'pZ': 2.62,
#        'vX0': -11.06,
#        'vY0': -135.0,
#        'vZ0': -5.7,
#        'x': 135.75,
#        'y': 167.91,
#        'x0': 2.46,
#        'y0': 50.0,
#        'z0': 5.86,
#        'aX': 16.93},
#       'breaks': {'breakAngle': 40.8,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2129,
#        'spinDirection': 137},
#       'zone': 4},
#      'hitData': {'launchSpeed': 82.61,
#       'launchAngle': 74.26,
#       'totalDistance': 0.0,
#       'trajectory': 'popup',
#       'hardness': 'medium',
#       'location': '3',
#       'coordinates': {'coordX': 161.12, 'coordY': 182.7}},
#      'index': 0,
#      'pfxId': '190428_171134',
#      'playId': '61c754f2-f946-4bad-8387-82765c19b8c9',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:11:28.000Z',
#      'endTime': '2019-04-28T17:11:43.000Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'atBatIndex': 0,
#    'playEndTime': '2019-04-28T17:11:43.000Z'},
#   {'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'Christian Yelich grounds out sharply, pitcher Steven Matz to first baseman Pete Alonso.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 1,
#     'halfInning': 'top',
#     'inning': 1,
#     'startTime': '2019-04-28T17:11:52.000Z',
#     'endTime': '2019-04-28T17:14:03.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 3, 'strikes': 2, 'outs': 2},
#    'matchup': {'batter': {'id': 592885,
#      'fullName': 'Christian Yelich',
#      'link': '/api/v1/people/592885'},
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitcher': {'id': 571927,
#      'fullName': 'Steven Matz',
#      'link': '/api/v1/people/571927'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_LHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3, 4, 5, 6],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 2},
#      'details': {'event': 'Field Out',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 592885,
#        'fullName': 'Christian Yelich',
#        'link': '/api/v1/people/592885'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 6},
#      'credits': [{'player': {'id': 571927, 'link': '/api/v1/people/571927'},
#        'position': {'code': '1',
#         'name': 'Pitcher',
#         'type': 'Pitcher',
#         'abbreviation': 'P'},
#        'credit': 'f_assist'},
#       {'player': {'id': 624413, 'link': '/api/v1/people/624413'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'S',
#        'description': 'Strike - Swinging'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1},
#      'pitchData': {'startSpeed': 93.5,
#       'endSpeed': 84.7,
#       'strikeZoneTop': 3.18,
#       'strikeZoneBottom': 1.7,
#       'coordinates': {'aY': 31.92,
#        'aZ': -23.18,
#        'pfxX': 12.85,
#        'pfxZ': 4.88,
#        'pX': -0.83,
#        'pZ': 2.96,
#        'vX0': -12.91,
#        'vY0': -135.51,
#        'vZ0': -3.29,
#        'x': 148.49,
#        'y': 158.72,
#        'x0': 2.35,
#        'y0': 50.0,
#        'z0': 5.83,
#        'aX': 23.69},
#       'breaks': {'breakAngle': 40.8,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2087,
#        'spinDirection': 112},
#       'zone': 11},
#      'index': 0,
#      'pfxId': '190428_171215',
#      'playId': 'e5903398-2786-4300-88ff-4c736e1fd31b',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:12:09.000Z',
#      'endTime': '2019-04-28T17:12:23.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1},
#      'pitchData': {'startSpeed': 86.8,
#       'endSpeed': 79.0,
#       'strikeZoneTop': 3.35,
#       'strikeZoneBottom': 1.81,
#       'coordinates': {'aY': 27.5,
#        'aZ': -29.3,
#        'pfxX': 1.6,
#        'pfxZ': 1.8,
#        'pX': -0.97,
#        'pZ': 3.26,
#        'vX0': -9.28,
#        'vY0': -126.02,
#        'vZ0': -0.24,
#        'x': 153.86,
#        'y': 150.45,
#        'x0': 2.57,
#        'y0': 50.0,
#        'z0': 5.74,
#        'aX': 2.55},
#       'breaks': {'breakAngle': 1.2,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2202,
#        'spinDirection': 170},
#       'zone': 11},
#      'index': 1,
#      'pfxId': '190428_171229',
#      'playId': '6a908185-6ad8-4c29-880a-3e75a0b64f06',
#      'pitchNumber': 2,
#      'startTime': '2019-04-28T17:12:23.000Z',
#      'endTime': '2019-04-28T17:12:38.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 1},
#      'pitchData': {'startSpeed': 92.8,
#       'endSpeed': 84.1,
#       'strikeZoneTop': 3.33,
#       'strikeZoneBottom': 1.71,
#       'coordinates': {'aY': 31.51,
#        'aZ': -18.82,
#        'pfxX': 11.45,
#        'pfxZ': 7.38,
#        'pX': -1.19,
#        'pZ': 1.77,
#        'vX0': -13.11,
#        'vY0': -134.32,
#        'vZ0': -6.91,
#        'x': 162.24,
#        'y': 190.89,
#        'x0': 2.29,
#        'y0': 50.0,
#        'z0': 5.74,
#        'aX': 20.73},
#       'breaks': {'breakAngle': 40.8,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2122,
#        'spinDirection': 124},
#       'zone': 13},
#      'index': 2,
#      'pfxId': '190428_171243',
#      'playId': '6d611699-3c88-4612-affb-39f28f0ee29d',
#      'pitchNumber': 3,
#      'startTime': '2019-04-28T17:12:38.000Z',
#      'endTime': '2019-04-28T17:12:54.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2},
#      'pitchData': {'startSpeed': 87.8,
#       'endSpeed': 79.6,
#       'strikeZoneTop': 3.3,
#       'strikeZoneBottom': 1.71,
#       'coordinates': {'aY': 29.17,
#        'aZ': -24.76,
#        'pfxX': 2.59,
#        'pfxZ': 4.55,
#        'pX': 0.02,
#        'pZ': 2.7,
#        'vX0': -7.36,
#        'vY0': -127.6,
#        'vZ0': -2.83,
#        'x': 116.21,
#        'y': 165.94,
#        'x0': 2.62,
#        'y0': 50.0,
#        'z0': 5.8,
#        'aX': 4.22},
#       'breaks': {'breakAngle': 6.0,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2080,
#        'spinDirection': 160},
#       'zone': 5},
#      'index': 3,
#      'pfxId': '190428_171300',
#      'playId': '3adb446a-14da-4dac-943e-983f76844aa5',
#      'pitchNumber': 4,
#      'startTime': '2019-04-28T17:12:54.000Z',
#      'endTime': '2019-04-28T17:13:11.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2},
#      'pitchData': {'startSpeed': 93.5,
#       'endSpeed': 84.6,
#       'strikeZoneTop': 3.19,
#       'strikeZoneBottom': 1.71,
#       'coordinates': {'aY': 32.23,
#        'aZ': -16.9,
#        'pfxX': 11.58,
#        'pfxZ': 8.28,
#        'pX': -0.18,
#        'pZ': 2.89,
#        'vX0': -11.0,
#        'vY0': -135.59,
#        'vZ0': -4.57,
#        'x': 124.02,
#        'y': 160.63,
#        'x0': 2.44,
#        'y0': 50.0,
#        'z0': 5.8,
#        'aX': 21.36},
#       'breaks': {'breakAngle': 46.8,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2041,
#        'spinDirection': 127},
#       'zone': 2},
#      'index': 4,
#      'pfxId': '190428_171318',
#      'playId': '1779f100-54f3-4cf7-a622-e123df7b3e85',
#      'pitchNumber': 5,
#      'startTime': '2019-04-28T17:13:11.000Z',
#      'endTime': '2019-04-28T17:13:33.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2},
#      'pitchData': {'startSpeed': 92.8,
#       'endSpeed': 84.3,
#       'strikeZoneTop': 3.29,
#       'strikeZoneBottom': 1.81,
#       'coordinates': {'aY': 30.54,
#        'aZ': -17.06,
#        'pfxX': 9.65,
#        'pfxZ': 8.34,
#        'pX': -2.01,
#        'pZ': 1.85,
#        'vX0': -14.33,
#        'vY0': -134.21,
#        'vZ0': -6.95,
#        'x': 193.47,
#        'y': 188.99,
#        'x0': 2.16,
#        'y0': 50.0,
#        'z0': 5.7,
#        'aX': 17.51},
#       'breaks': {'breakAngle': 37.2,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2106,
#        'spinDirection': 134},
#       'zone': 13},
#      'index': 5,
#      'pfxId': '190428_171338',
#      'playId': 'da0e1c38-0bd2-40a4-a801-0b5e7d8c04ae',
#      'pitchNumber': 6,
#      'startTime': '2019-04-28T17:13:33.000Z',
#      'endTime': '2019-04-28T17:13:52.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X',
#        'description': 'Hit Into Play - Out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2},
#      'pitchData': {'startSpeed': 92.9,
#       'endSpeed': 84.7,
#       'strikeZoneTop': 3.28,
#       'strikeZoneBottom': 1.82,
#       'coordinates': {'aY': 29.96,
#        'aZ': -21.09,
#        'pfxX': 10.91,
#        'pfxZ': 6.05,
#        'pX': -0.11,
#        'pZ': 2.08,
#        'vX0': -10.78,
#        'vY0': -134.73,
#        'vZ0': -5.59,
#        'x': 121.2,
#        'y': 182.54,
#        'x0': 2.53,
#        'y0': 50.0,
#        'z0': 5.68,
#        'aX': 20.01},
#       'breaks': {'breakAngle': 38.4,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2070,
#        'spinDirection': 119},
#       'zone': 8},
#      'hitData': {'launchSpeed': 111.22,
#       'launchAngle': -15.84,
#       'totalDistance': 53.31,
#       'trajectory': 'ground_ball',
#       'hardness': 'hard',
#       'location': '1',
#       'coordinates': {'coordX': 134.2, 'coordY': 180.16}},
#      'index': 6,
#      'pfxId': '190428_171358',
#      'playId': '2407d9da-e68f-480d-ab21-08f971c21b49',
#      'pitchNumber': 7,
#      'startTime': '2019-04-28T17:13:52.000Z',
#      'endTime': '2019-04-28T17:14:03.000Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'atBatIndex': 1,
#    'playEndTime': '2019-04-28T17:14:03.000Z'},
#   {'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'Ryan Braun grounds out, third baseman Todd Frazier to first baseman Pete Alonso.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 2,
#     'halfInning': 'top',
#     'inning': 1,
#     'startTime': '2019-04-28T17:14:17.000Z',
#     'endTime': '2019-04-28T17:16:53.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 2, 'strikes': 2, 'outs': 3},
#    'matchup': {'batter': {'id': 460075,
#      'fullName': 'Ryan Braun',
#      'link': '/api/v1/people/460075'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 571927,
#      'fullName': 'Steven Matz',
#      'link': '/api/v1/people/571927'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1, 2, 3, 4, 5, 6, 7],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 3},
#      'details': {'event': 'Field Out',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 460075,
#        'fullName': 'Ryan Braun',
#        'link': '/api/v1/people/460075'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 7},
#      'credits': [{'player': {'id': 453943, 'link': '/api/v1/people/453943'},
#        'position': {'code': '5',
#         'name': 'Third Base',
#         'type': 'Infielder',
#         'abbreviation': '3B'},
#        'credit': 'f_assist'},
#       {'player': {'id': 624413, 'link': '/api/v1/people/624413'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'S',
#        'description': 'Strike - Swinging'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1},
#      'pitchData': {'startSpeed': 93.1,
#       'endSpeed': 84.5,
#       'strikeZoneTop': 3.64,
#       'strikeZoneBottom': 1.76,
#       'coordinates': {'aY': 30.96,
#        'aZ': -17.9,
#        'pfxX': 10.5,
#        'pfxZ': 7.75,
#        'pX': 0.78,
#        'pZ': 3.83,
#        'vX0': -7.83,
#        'vY0': -135.23,
#        'vZ0': -2.42,
#        'x': 87.32,
#        'y': 135.3,
#        'x0': 2.35,
#        'y0': 50.0,
#        'z0': 6.0,
#        'aX': 19.34},
#       'breaks': {'breakAngle': 43.2,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2069,
#        'spinDirection': 128},
#       'zone': 12},
#      'index': 0,
#      'pfxId': '190428_171437',
#      'playId': '7edbab09-c053-45b4-8880-0f8410bd140b',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:14:31.000Z',
#      'endTime': '2019-04-28T17:14:46.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 0, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SL', 'description': 'Slider'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1},
#      'pitchData': {'startSpeed': 88.3,
#       'endSpeed': 80.3,
#       'strikeZoneTop': 3.66,
#       'strikeZoneBottom': 1.79,
#       'coordinates': {'aY': 28.16,
#        'aZ': -27.12,
#        'pfxX': 2.92,
#        'pfxZ': 3.05,
#        'pX': -0.52,
#        'pZ': 4.06,
#        'vX0': -8.73,
#        'vY0': -128.26,
#        'vZ0': 0.59,
#        'x': 137.0,
#        'y': 129.19,
#        'x0': 2.55,
#        'y0': 50.0,
#        'z0': 5.95,
#        'aX': 4.84},
#       'breaks': {'breakAngle': 6.0,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2078,
#        'spinDirection': 151},
#       'zone': 11},
#      'index': 1,
#      'pfxId': '190428_171451',
#      'playId': '3d86c9b6-c5d3-4dd4-bb1d-fc427af10325',
#      'pitchNumber': 2,
#      'startTime': '2019-04-28T17:14:46.000Z',
#      'endTime': '2019-04-28T17:15:02.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2},
#      'pitchData': {'startSpeed': 92.7,
#       'endSpeed': 84.0,
#       'strikeZoneTop': 3.65,
#       'strikeZoneBottom': 1.81,
#       'coordinates': {'aY': 31.4,
#        'aZ': -20.24,
#        'pfxX': 10.99,
#        'pfxZ': 6.57,
#        'pX': -0.61,
#        'pZ': 3.15,
#        'vX0': -11.46,
#        'vY0': -134.47,
#        'vZ0': -3.47,
#        'x': 140.21,
#        'y': 153.75,
#        'x0': 2.3,
#        'y0': 50.0,
#        'z0': 5.91,
#        'aX': 19.96},
#       'breaks': {'breakAngle': 39.6,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2145,
#        'spinDirection': 123},
#       'zone': 1},
#      'index': 2,
#      'pfxId': '190428_171507',
#      'playId': 'ed238c70-1ef9-4d19-8cf7-63325d1367f9',
#      'pitchNumber': 3,
#      'startTime': '2019-04-28T17:15:02.000Z',
#      'endTime': '2019-04-28T17:15:19.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(0, 34, 255, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'CU', 'description': 'Curveball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2},
#      'pitchData': {'startSpeed': 78.3,
#       'endSpeed': 71.5,
#       'strikeZoneTop': 3.6,
#       'strikeZoneBottom': 1.79,
#       'coordinates': {'aY': 24.0,
#        'aZ': -39.29,
#        'pfxX': -8.02,
#        'pfxZ': -5.5,
#        'pX': -0.27,
#        'pZ': 2.44,
#        'vX0': -4.22,
#        'vY0': -113.94,
#        'vZ0': 1.07,
#        'x': 127.44,
#        'y': 172.95,
#        'x0': 2.66,
#        'y0': 50.0,
#        'z0': 5.89,
#        'aX': -10.37},
#       'breaks': {'breakAngle': 15.6,
#        'breakLength': 13.2,
#        'breakY': 24.0,
#        'spinRate': 2565,
#        'spinDirection': 300},
#       'zone': 4},
#      'index': 3,
#      'pfxId': '190428_171528',
#      'playId': 'a2e08597-ecb8-402d-84c2-485c9d5307de',
#      'pitchNumber': 4,
#      'startTime': '2019-04-28T17:15:19.000Z',
#      'endTime': '2019-04-28T17:15:44.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2},
#      'pitchData': {'startSpeed': 93.8,
#       'endSpeed': 84.5,
#       'strikeZoneTop': 3.64,
#       'strikeZoneBottom': 1.76,
#       'coordinates': {'aY': 33.29,
#        'aZ': -19.8,
#        'pfxX': 11.02,
#        'pfxZ': 6.7,
#        'pX': -0.34,
#        'pZ': 3.4,
#        'vX0': -10.96,
#        'vY0': -135.89,
#        'vZ0': -2.99,
#        'x': 129.95,
#        'y': 146.88,
#        'x0': 2.34,
#        'y0': 50.0,
#        'z0': 5.91,
#        'aX': 20.34},
#       'breaks': {'breakAngle': 40.8,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2152,
#        'spinDirection': 124},
#       'zone': 1},
#      'index': 4,
#      'pfxId': '190428_171554',
#      'playId': '09c1e5c7-b281-4079-bcba-df2505bceeab',
#      'pitchNumber': 5,
#      'startTime': '2019-04-28T17:15:44.000Z',
#      'endTime': '2019-04-28T17:16:04.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Foul',
#       'code': 'F',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 2},
#      'pitchData': {'startSpeed': 92.7,
#       'endSpeed': 83.8,
#       'strikeZoneTop': 3.6,
#       'strikeZoneBottom': 1.81,
#       'coordinates': {'aY': 32.21,
#        'aZ': -14.91,
#        'pfxX': 10.51,
#        'pfxZ': 9.53,
#        'pX': 0.89,
#        'pZ': 2.21,
#        'vX0': -7.66,
#        'vY0': -134.52,
#        'vZ0': -6.71,
#        'x': 83.22,
#        'y': 179.18,
#        'x0': 2.42,
#        'y0': 50.0,
#        'z0': 5.81,
#        'aX': 19.05},
#       'breaks': {'breakAngle': 46.8,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2110,
#        'spinDirection': 132},
#       'zone': 14},
#      'index': 5,
#      'pfxId': '190428_171614',
#      'playId': '36697e02-8959-4809-b3ff-00880b4c784b',
#      'pitchNumber': 6,
#      'startTime': '2019-04-28T17:16:04.000Z',
#      'endTime': '2019-04-28T17:16:25.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(50, 0, 221, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'SI', 'description': 'Sinker'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2},
#      'pitchData': {'startSpeed': 93.7,
#       'endSpeed': 85.0,
#       'strikeZoneTop': 3.61,
#       'strikeZoneBottom': 1.85,
#       'coordinates': {'aY': 31.26,
#        'aZ': -18.23,
#        'pfxX': 11.95,
#        'pfxZ': 7.53,
#        'pX': -1.5,
#        'pZ': 2.36,
#        'vX0': -14.21,
#        'vY0': -135.6,
#        'vZ0': -5.56,
#        'x': 174.13,
#        'y': 174.94,
#        'x0': 2.27,
#        'y0': 50.0,
#        'z0': 5.72,
#        'aX': 22.12},
#       'breaks': {'breakAngle': 44.4,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2026,
#        'spinDirection': 124},
#       'zone': 13},
#      'index': 6,
#      'pfxId': '190428_171630',
#      'playId': 'bc5bee7e-a891-4c0e-9299-dca1524a97c8',
#      'pitchNumber': 7,
#      'startTime': '2019-04-28T17:16:25.000Z',
#      'endTime': '2019-04-28T17:16:42.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X',
#        'description': 'Hit Into Play - Out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(0, 85, 254, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'CH', 'description': 'Changeup'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 2},
#      'pitchData': {'startSpeed': 85.6,
#       'endSpeed': 77.9,
#       'strikeZoneTop': 3.63,
#       'strikeZoneBottom': 1.84,
#       'coordinates': {'aY': 26.88,
#        'aZ': -26.59,
#        'pfxX': 12.75,
#        'pfxZ': 3.61,
#        'pX': 0.11,
#        'pZ': 1.82,
#        'vX0': -9.68,
#        'vY0': -124.21,
#        'vZ0': -4.0,
#        'x': 112.95,
#        'y': 189.66,
#        'x0': 2.41,
#        'y0': 50.0,
#        'z0': 5.68,
#        'aX': 19.74},
#       'breaks': {'breakAngle': 32.4,
#        'breakLength': 8.4,
#        'breakY': 24.0,
#        'spinRate': 2314,
#        'spinDirection': 105},
#       'zone': 8},
#      'hitData': {'launchSpeed': 102.52,
#       'launchAngle': -11.37,
#       'totalDistance': 109.99,
#       'trajectory': 'ground_ball',
#       'hardness': 'medium',
#       'location': '5',
#       'coordinates': {'coordX': 110.83, 'coordY': 174.06}},
#      'index': 7,
#      'pfxId': '190428_171650',
#      'playId': '03e04e83-e32c-4982-96e3-37093a7bd9a3',
#      'pitchNumber': 8,
#      'startTime': '2019-04-28T17:16:42.000Z',
#      'endTime': '2019-04-28T17:16:53.000Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'atBatIndex': 2,
#    'playEndTime': '2019-04-28T17:16:53.000Z'},
#   {'result': {'type': 'atBat',
#     'event': 'Groundout',
#     'eventType': 'field_out',
#     'description': 'Jeff McNeil grounds out, second baseman Hernan Perez to first baseman Jesus Aguilar.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 3,
#     'halfInning': 'bottom',
#     'inning': 1,
#     'startTime': '2019-04-28T17:18:51.000Z',
#     'endTime': '2019-04-28T17:20:07.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': True,
#     'captivatingIndex': 0},
#    'count': {'balls': 0, 'strikes': 1, 'outs': 1},
#    'matchup': {'batter': {'id': 643446,
#      'fullName': 'Jeff McNeil',
#      'link': '/api/v1/people/643446'},
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitcher': {'id': 461829,
#      'fullName': 'Gio Gonzalez',
#      'link': '/api/v1/people/461829'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_LHB', 'menOnBase': 'Empty'}},
#    'pitchIndex': [0, 1],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': None,
#       'outBase': '1B',
#       'isOut': True,
#       'outNumber': 1},
#      'details': {'event': 'Field Out',
#       'eventType': 'field_out',
#       'movementReason': None,
#       'runner': {'id': 643446,
#        'fullName': 'Jeff McNeil',
#        'link': '/api/v1/people/643446'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 1},
#      'credits': [{'player': {'id': 541650, 'link': '/api/v1/people/541650'},
#        'position': {'code': '4',
#         'name': 'Second Base',
#         'type': 'Infielder',
#         'abbreviation': '2B'},
#        'credit': 'f_assist'},
#       {'player': {'id': 542583, 'link': '/api/v1/people/542583'},
#        'position': {'code': '3',
#         'name': 'First Base',
#         'type': 'Infielder',
#         'abbreviation': '1B'},
#        'credit': 'f_putout'}]}],
#    'playEvents': [{'details': {'call': {'code': 'S',
#        'description': 'Strike - Swinging'},
#       'description': 'Foul Bunt',
#       'code': 'L',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1},
#      'pitchData': {'startSpeed': 89.0,
#       'endSpeed': 80.6,
#       'strikeZoneTop': 3.28,
#       'strikeZoneBottom': 1.53,
#       'coordinates': {'aY': 29.5,
#        'aZ': -16.34,
#        'pfxX': 8.19,
#        'pfxZ': 9.47,
#        'pX': 0.5,
#        'pZ': 2.27,
#        'vX0': -5.58,
#        'vY0': -129.17,
#        'vZ0': -5.91,
#        'x': 97.89,
#        'y': 177.43,
#        'x0': 1.64,
#        'y0': 50.0,
#        'z0': 5.86,
#        'aX': 13.7},
#       'breaks': {'breakAngle': 34.8,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2312,
#        'spinDirection': 139},
#       'zone': 6},
#      'index': 0,
#      'pfxId': '190428_171920',
#      'playId': '9a1468fc-91f4-4ab8-8f1d-3e69ffaf3369',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:19:13.000Z',
#      'endTime': '2019-04-28T17:19:57.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X',
#        'description': 'Hit Into Play - Out(s)'},
#       'description': 'In play, out(s)',
#       'code': 'X',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(0, 34, 255, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'CU', 'description': 'Curveball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1},
#      'pitchData': {'startSpeed': 74.7,
#       'endSpeed': 67.4,
#       'strikeZoneTop': 3.55,
#       'strikeZoneBottom': 1.73,
#       'coordinates': {'aY': 23.97,
#        'aZ': -43.81,
#        'pfxX': -6.6,
#        'pfxZ': -10.1,
#        'pX': -0.5,
#        'pZ': 2.37,
#        'vX0': -2.66,
#        'vY0': -108.25,
#        'vZ0': 2.14,
#        'x': 136.19,
#        'y': 174.85,
#        'x0': 1.61,
#        'y0': 50.0,
#        'z0': 6.27,
#        'aX': -7.6},
#       'breaks': {'breakAngle': 10.8,
#        'breakLength': 15.6,
#        'breakY': 24.0,
#        'spinRate': 2593,
#        'spinDirection': 322},
#       'zone': 4},
#      'hitData': {'launchSpeed': 94.53,
#       'launchAngle': -1.63,
#       'totalDistance': 139.48,
#       'trajectory': 'ground_ball',
#       'hardness': 'medium',
#       'location': '4',
#       'coordinates': {'coordX': 144.36, 'coordY': 157.3}},
#      'index': 1,
#      'pfxId': '190428_172007',
#      'playId': '1895d91a-76f2-44c5-baed-4979685b7685',
#      'pitchNumber': 2,
#      'startTime': '2019-04-28T17:19:57.000Z',
#      'endTime': '2019-04-28T17:20:07.000Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'atBatIndex': 3,
#    'playEndTime': '2019-04-28T17:20:07.000Z'},
#   {'result': {'type': 'atBat',
#     'event': 'Triple',
#     'eventType': 'triple',
#     'description': 'Umpire reviewed (home run), call on the field was upheld: Pete Alonso triples (1) on a sharp fly ball to left fielder Ryan Braun.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 4,
#     'halfInning': 'bottom',
#     'inning': 1,
#     'startTime': '2019-04-28T17:20:15.000Z',
#     'endTime': '2019-04-28T17:22:25.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': True,
#     'hasOut': False,
#     'captivatingIndex': 35},
#    'count': {'balls': 3, 'strikes': 2, 'outs': 1},
#    'matchup': {'batter': {'id': 624413,
#      'fullName': 'Pete Alonso',
#      'link': '/api/v1/people/624413'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 461829,
#      'fullName': 'Gio Gonzalez',
#      'link': '/api/v1/people/461829'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'RISP'}},
#    'pitchIndex': [0, 1, 2, 3, 4, 5],
#    'actionIndex': [],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': '3B',
#       'outBase': None,
#       'isOut': None,
#       'outNumber': None},
#      'details': {'event': 'Triple',
#       'eventType': 'triple',
#       'movementReason': None,
#       'runner': {'id': 624413,
#        'fullName': 'Pete Alonso',
#        'link': '/api/v1/people/624413'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 5},
#      'credits': [{'player': {'id': 460075, 'link': '/api/v1/people/460075'},
#        'position': {'code': '7',
#         'name': 'Outfielder',
#         'type': 'Outfielder',
#         'abbreviation': 'LF'},
#        'credit': 'f_fielded_ball'}]}],
#    'playEvents': [{'details': {'call': {'code': 'B',
#        'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(187, 0, 69, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FT', 'description': 'Two-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 0},
#      'pitchData': {'startSpeed': 88.6,
#       'endSpeed': 80.4,
#       'strikeZoneTop': 3.36,
#       'strikeZoneBottom': 1.65,
#       'coordinates': {'aY': 28.9,
#        'aZ': -20.08,
#        'pfxX': 12.07,
#        'pfxZ': 7.28,
#        'pX': 1.67,
#        'pZ': 2.37,
#        'vX0': -4.8,
#        'vY0': -128.65,
#        'vZ0': -4.68,
#        'x': 53.31,
#        'y': 174.84,
#        'x0': 2.0,
#        'y0': 50.0,
#        'z0': 5.79,
#        'aX': 20.05},
#       'breaks': {'breakAngle': 42.0,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2245,
#        'spinDirection': 120},
#       'zone': 14},
#      'index': 0,
#      'pfxId': '190428_172041',
#      'playId': 'ff92a31a-7794-410d-8699-62308e2c7f3e',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:20:36.000Z',
#      'endTime': '2019-04-28T17:20:51.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 2, 'strikes': 0},
#      'pitchData': {'startSpeed': 89.7,
#       'endSpeed': 81.3,
#       'strikeZoneTop': 3.33,
#       'strikeZoneBottom': 1.57,
#       'coordinates': {'aY': 28.99,
#        'aZ': -14.37,
#        'pfxX': 6.25,
#        'pfxZ': 10.42,
#        'pX': 0.68,
#        'pZ': 4.08,
#        'vX0': -5.0,
#        'vY0': -130.32,
#        'vZ0': -2.01,
#        'x': 91.2,
#        'y': 128.74,
#        'x0': 1.82,
#        'y0': 50.0,
#        'z0': 5.95,
#        'aX': 10.68},
#       'breaks': {'breakAngle': 32.4,
#        'breakLength': 3.6,
#        'breakY': 24.0,
#        'spinRate': 2304,
#        'spinDirection': 151},
#       'zone': 12},
#      'index': 1,
#      'pfxId': '190428_172056',
#      'playId': 'b0740604-efe7-4b19-bebe-2ad4bc245cb9',
#      'pitchNumber': 2,
#      'startTime': '2019-04-28T17:20:51.000Z',
#      'endTime': '2019-04-28T17:21:09.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(187, 0, 69, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'FT', 'description': 'Two-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 0},
#      'pitchData': {'startSpeed': 90.2,
#       'endSpeed': 81.5,
#       'strikeZoneTop': 3.42,
#       'strikeZoneBottom': 1.65,
#       'coordinates': {'aY': 31.2,
#        'aZ': -21.66,
#        'pfxX': 12.47,
#        'pfxZ': 6.14,
#        'pX': 1.55,
#        'pZ': 2.27,
#        'vX0': -5.21,
#        'vY0': -130.93,
#        'vZ0': -4.55,
#        'x': 58.01,
#        'y': 177.43,
#        'x0': 1.96,
#        'y0': 50.0,
#        'z0': 5.68,
#        'aX': 21.35},
#       'breaks': {'breakAngle': 42.0,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 2216,
#        'spinDirection': 115},
#       'zone': 14},
#      'index': 2,
#      'pfxId': '190428_172115',
#      'playId': '382b8422-b640-4b68-aaef-1d3f37d4e555',
#      'pitchNumber': 3,
#      'startTime': '2019-04-28T17:21:09.000Z',
#      'endTime': '2019-04-28T17:21:25.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Called Strike',
#       'code': 'C',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(187, 0, 69, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FT', 'description': 'Two-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 1},
#      'pitchData': {'startSpeed': 89.5,
#       'endSpeed': 81.6,
#       'strikeZoneTop': 3.32,
#       'strikeZoneBottom': 1.62,
#       'coordinates': {'aY': 28.27,
#        'aZ': -20.15,
#        'pfxX': 9.73,
#        'pfxZ': 7.04,
#        'pX': 1.17,
#        'pZ': 2.86,
#        'vX0': -4.85,
#        'vY0': -130.13,
#        'vZ0': -3.66,
#        'x': 72.6,
#        'y': 161.73,
#        'x0': 1.79,
#        'y0': 50.0,
#        'z0': 5.82,
#        'aX': 16.62},
#       'breaks': {'breakAngle': 37.2,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2195,
#        'spinDirection': 126},
#       'zone': 12},
#      'index': 3,
#      'pfxId': '190428_172130',
#      'playId': '40ee2a11-cbb9-4f61-94c4-894e382783e1',
#      'pitchNumber': 4,
#      'startTime': '2019-04-28T17:21:25.000Z',
#      'endTime': '2019-04-28T17:21:40.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(187, 0, 69, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FT', 'description': 'Two-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2},
#      'pitchData': {'startSpeed': 90.6,
#       'endSpeed': 82.4,
#       'strikeZoneTop': 3.37,
#       'strikeZoneBottom': 1.66,
#       'coordinates': {'aY': 29.77,
#        'aZ': -20.2,
#        'pfxX': 10.61,
#        'pfxZ': 6.86,
#        'pX': 1.39,
#        'pZ': 2.72,
#        'vX0': -4.95,
#        'vY0': -131.74,
#        'vZ0': -4.02,
#        'x': 64.1,
#        'y': 165.3,
#        'x0': 1.92,
#        'y0': 50.0,
#        'z0': 5.77,
#        'aX': 18.51},
#       'breaks': {'breakAngle': 39.6,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2230,
#        'spinDirection': 123},
#       'zone': 12},
#      'index': 4,
#      'pfxId': '190428_172145',
#      'playId': '7527cc8a-0263-49ae-9e09-0dcd5c04f5ae',
#      'pitchNumber': 5,
#      'startTime': '2019-04-28T17:21:40.000Z',
#      'endTime': '2019-04-28T17:22:03.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'X',
#        'description': 'Hit Into Play - Out(s)'},
#       'description': 'In play, no out',
#       'code': 'D',
#       'ballColor': 'rgba(26, 86, 190, 1.0)',
#       'trailColor': 'rgba(188, 0, 33, 1.0)',
#       'isInPlay': True,
#       'isStrike': False,
#       'isBall': False,
#       'type': {'code': 'FF', 'description': 'Four-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 3, 'strikes': 2},
#      'pitchData': {'startSpeed': 91.2,
#       'endSpeed': 82.9,
#       'strikeZoneTop': 3.35,
#       'strikeZoneBottom': 1.67,
#       'coordinates': {'aY': 29.6,
#        'aZ': -15.89,
#        'pfxX': 6.69,
#        'pfxZ': 9.19,
#        'pX': 0.14,
#        'pZ': 3.27,
#        'vX0': -5.84,
#        'vY0': -132.56,
#        'vZ0': -3.86,
#        'x': 111.54,
#        'y': 150.34,
#        'x0': 1.51,
#        'y0': 50.0,
#        'z0': 5.92,
#        'aX': 11.85},
#       'breaks': {'breakAngle': 32.4,
#        'breakLength': 4.8,
#        'breakY': 24.0,
#        'spinRate': 2282,
#        'spinDirection': 146},
#       'zone': 2},
#      'hitData': {'launchSpeed': 102.36,
#       'launchAngle': 38.31,
#       'totalDistance': 362.01,
#       'trajectory': 'fly_ball',
#       'hardness': 'hard',
#       'location': '7',
#       'coordinates': {'coordX': 67.95, 'coordY': 57.2}},
#      'index': 5,
#      'pfxId': '190428_172222',
#      'playId': '7cbcfe07-eb15-4ae6-b2ba-0cce37d30553',
#      'pitchNumber': 6,
#      'startTime': '2019-04-28T17:22:03.000Z',
#      'endTime': '2019-04-28T17:22:25.000Z',
#      'isPitch': True,
#      'type': 'pitch'}],
#    'atBatIndex': 4,
#    'playEndTime': '2019-04-28T17:22:25.000Z'},
#   {'result': {'type': 'atBat',
#     'event': 'Walk',
#     'eventType': 'walk',
#     'description': 'Juan Lagares walks.',
#     'rbi': 0,
#     'awayScore': 0,
#     'homeScore': 0},
#    'about': {'atBatIndex': 5,
#     'halfInning': 'bottom',
#     'inning': 1,
#     'startTime': '2019-04-28T17:25:31.000Z',
#     'endTime': '2019-04-28T17:30:48.000Z',
#     'isComplete': True,
#     'isScoringPlay': False,
#     'hasReview': False,
#     'hasOut': False,
#     'captivatingIndex': 0},
#    'count': {'balls': 4, 'strikes': 2, 'outs': 1},
#    'matchup': {'batter': {'id': 501571,
#      'fullName': 'Juan Lagares',
#      'link': '/api/v1/people/501571'},
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitcher': {'id': 461829,
#      'fullName': 'Gio Gonzalez',
#      'link': '/api/v1/people/461829'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'batterHotColdZones': [],
#     'pitcherHotColdZones': [],
#     'splits': {'batter': 'vs_LHP', 'pitcher': 'vs_RHB', 'menOnBase': 'RISP'}},
#    'pitchIndex': [0, 3, 4, 5, 6, 7, 8],
#    'actionIndex': [1, 2],
#    'runnerIndex': [0],
#    'runners': [{'movement': {'start': None,
#       'end': '1B',
#       'outBase': None,
#       'isOut': None,
#       'outNumber': None},
#      'details': {'event': 'Walk',
#       'eventType': 'walk',
#       'movementReason': None,
#       'runner': {'id': 501571,
#        'fullName': 'Juan Lagares',
#        'link': '/api/v1/people/501571'},
#       'responsiblePitcher': None,
#       'isScoringEvent': False,
#       'rbi': False,
#       'earned': False,
#       'teamUnearned': False,
#       'playIndex': 8},
#      'credits': []}],
#    'playEvents': [{'details': {'call': {'code': 'S',
#        'description': 'Strike - Swinging'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
#       'trailColor': 'rgba(187, 0, 69, 1.0)',
#       'isInPlay': False,
#       'isStrike': True,
#       'isBall': False,
#       'type': {'code': 'FT', 'description': 'Two-Seam Fastball'},
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1},
#      'pitchData': {'startSpeed': 88.4,
#       'endSpeed': 79.9,
#       'strikeZoneTop': 3.63,
#       'strikeZoneBottom': 1.76,
#       'coordinates': {'aY': 29.72,
#        'aZ': -18.13,
#        'pfxX': 10.53,
#        'pfxZ': 8.51,
#        'pX': 2.27,
#        'pZ': 3.77,
#        'vX0': -2.08,
#        'vY0': -128.49,
#        'vZ0': -2.35,
#        'x': 30.46,
#        'y': 136.98,
#        'x0': 1.73,
#        'y0': 50.0,
#        'z0': 6.12,
#        'aX': 17.38},
#       'breaks': {'breakAngle': 42.0,
#        'breakLength': 6.0,
#        'breakY': 24.0,
#        'spinRate': 2112,
#        'spinDirection': 129},
#       'zone': 12},
#      'index': 0,
#      'pfxId': '190428_172543',
#      'playId': 'd77b6ea2-1763-4662-a4f1-4ff616264a52',
#      'pitchNumber': 1,
#      'startTime': '2019-04-28T17:25:38.000Z',
#      'endTime': '2019-04-28T17:26:13.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'description': 'Injury Delay.',
#       'event': 'Game Advisory',
#       'awayScore': 0,
#       'homeScore': 0,
#       'isScoringPlay': False,
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1, 'outs': 1},
#      'index': 1,
#      'startTime': '2019-04-28T17:26:13.000Z',
#      'endTime': '2019-04-28T17:27:55.000Z',
#      'isPitch': False,
#      'type': 'action',
#      'player': {'id': 429664, 'link': '/api/v1/people/429664'}},
#     {'details': {'description': 'Offensive Substitution: Pinch-hitter Juan Lagares replaces Robinson Cano.',
#       'event': 'Offensive Substitution',
#       'eventType': 'offensive_substitution',
#       'awayScore': 0,
#       'homeScore': 0,
#       'isScoringPlay': False,
#       'hasReview': False},
#      'count': {'balls': 0, 'strikes': 1, 'outs': 1},
#      'index': 2,
#      'startTime': '2019-04-28T17:27:55.000Z',
#      'endTime': '2019-04-28T17:28:41.000Z',
#      'isPitch': False,
#      'type': 'action',
#      'player': {'id': 501571, 'link': '/api/v1/people/501571'},
#      'battingOrder': '302'},
#     {'details': {'call': {'code': 'B', 'description': 'Ball - Called'},
#       'description': 'Ball',
#       'code': 'B',
#       'ballColor': 'rgba(39, 161, 39, 1.0)',
#       'trailColor': 'rgba(0, 85, 254, 1.0)',
#       'isInPlay': False,
#       'isStrike': False,
#       'isBall': True,
#       'type': {'code': 'CH', 'description': 'Changeup'},
#       'hasReview': False},
#      'count': {'balls': 1, 'strikes': 1},
#      'pitchData': {'startSpeed': 81.4,
#       'endSpeed': 74.6,
#       'strikeZoneTop': 3.52,
#       'strikeZoneBottom': 1.74,
#       'coordinates': {'aY': 22.94,
#        'aZ': -24.26,
#        'pfxX': 7.62,
#        'pfxZ': 5.59,
#        'pX': 1.79,
#        'pZ': 2.39,
#        'vX0': -2.62,
#        'vY0': -118.37,
#        'vZ0': -3.01,
#        'x': 48.84,
#        'y': 174.24,
#        'x0': 1.92,
#        'y0': 50.0,
#        'z0': 5.91,
#        'aX': 10.8},
#       'breaks': {'breakAngle': 22.8,
#        'breakLength': 7.2,
#        'breakY': 24.0,
#        'spinRate': 1588,
#        'spinDirection': 126},
#       'zone': 14},
#      'index': 3,
#      'pfxId': '190428_172847',
#      'playId': '266c8627-15be-485f-a9ff-fce6320eeb91',
#      'pitchNumber': 2,
#      'startTime': '2019-04-28T17:28:41.000Z',
#      'endTime': '2019-04-28T17:28:58.000Z',
#      'isPitch': True,
#      'type': 'pitch'},
#     {'details': {'call': {'code': 'S', 'description': 'Strike - Swinging'},
#       'description': 'Swinging Strike',
#       'code': 'S',
#       'ballColor': 'rgba(170, 21, 11, 1.0)',
# ...
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 542583,
#        'fullName': 'Jesus Aguilar',
#        'link': '/api/v1/people/542583'},
#       'coordinates': {'x': 108.29, 'y': 170.51},
#       'type': 'O',
#       'description': 'Grounded Into DP'}],
#     'home': [{'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 4,
#       'pitcher': {'id': 461829,
#        'fullName': 'Gio Gonzalez',
#        'link': '/api/v1/people/461829'},
#       'batter': {'id': 607043,
#        'fullName': 'Brandon Nimmo',
#        'link': '/api/v1/people/607043'},
#       'coordinates': {'x': 158.58, 'y': 169.49},
#       'type': 'O',
#       'description': 'Groundout'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 4,
#       'pitcher': {'id': 461829,
#        'fullName': 'Gio Gonzalez',
#        'link': '/api/v1/people/461829'},
#       'batter': {'id': 642708,
#        'fullName': 'Amed Rosario',
#        'link': '/api/v1/people/642708'},
#       'coordinates': {'x': 145.37, 'y': 102.95},
#       'type': 'O',
#       'description': 'Flyout'}]}},
#   {'startIndex': 30,
#    'endIndex': 35,
#    'top': [30, 31, 32],
#    'bottom': [33, 34, 35],
#    'hits': {'away': [{'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 519058,
#        'fullName': 'Mike Moustakas',
#        'link': '/api/v1/people/519058'},
#       'coordinates': {'x': 153.99, 'y': 136.57},
#       'type': 'O',
#       'description': 'Pop Out'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 541650,
#        'fullName': 'Hernan Perez',
#        'link': '/api/v1/people/541650'},
#       'coordinates': {'x': 112.36, 'y': 178.13},
#       'type': 'O',
#       'description': 'Groundout'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 444489,
#        'fullName': 'Manny Pina',
#        'link': '/api/v1/people/444489'},
#       'coordinates': {'x': 105.75, 'y': 178.64},
#       'type': 'O',
#       'description': 'Groundout'}],
#     'home': [{'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 461829,
#        'fullName': 'Gio Gonzalez',
#        'link': '/api/v1/people/461829'},
#       'batter': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'coordinates': {'x': 108.29, 'y': 178.13},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 461829,
#        'fullName': 'Gio Gonzalez',
#        'link': '/api/v1/people/461829'},
#       'batter': {'id': 643446,
#        'fullName': 'Jeff McNeil',
#        'link': '/api/v1/people/643446'},
#       'coordinates': {'x': 191.62, 'y': 100.0},
#       'type': 'O',
#       'description': 'Double Play'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 5,
#       'pitcher': {'id': 461829,
#        'fullName': 'Gio Gonzalez',
#        'link': '/api/v1/people/461829'},
#       'batter': {'id': 624413,
#        'fullName': 'Pete Alonso',
#        'link': '/api/v1/people/624413'},
#       'coordinates': {'x': 106.26, 'y': 153.24},
#       'type': 'O',
#       'description': 'Groundout'}]}},
#   {'startIndex': 36,
#    'endIndex': 41,
#    'top': [36, 37, 38],
#    'bottom': [39, 40, 41],
#    'hits': {'away': [{'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 606115,
#        'fullName': 'Orlando Arcia',
#        'link': '/api/v1/people/606115'},
#       'coordinates': {'x': 146.9, 'y': 166.44},
#       'type': 'O',
#       'description': 'Groundout'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 519346,
#        'fullName': 'Eric Thames',
#        'link': '/api/v1/people/519346'},
#       'coordinates': {'x': 125.63438192882447, 'y': 180.86453146681538},
#       'type': 'O',
#       'description': 'Lineout'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 456715,
#        'fullName': 'Lorenzo Cain',
#        'link': '/api/v1/people/456715'},
#       'coordinates': {'x': 150.45380976095618, 'y': 156.2848592659392},
#       'type': 'O',
#       'description': 'Pop Out'}],
#     'home': [{'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 6,
#       'pitcher': {'id': 458006,
#        'fullName': 'Matt Albers',
#        'link': '/api/v1/people/458006'},
#       'batter': {'id': 467092,
#        'fullName': 'Wilson Ramos',
#        'link': '/api/v1/people/467092'},
#       'coordinates': {'x': 134.2, 'y': 133.93},
#       'type': 'O',
#       'description': 'Groundout'}]}},
#   {'startIndex': 42,
#    'endIndex': 53,
#    'top': [42, 43, 44, 45, 46],
#    'bottom': [47, 48, 49, 50, 51, 52, 53],
#    'hits': {'away': [{'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 592325,
#        'fullName': 'Ben Gamel',
#        'link': '/api/v1/people/592325'},
#       'coordinates': {'x': 126.22, 'y': 118.9},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 460075,
#        'fullName': 'Ryan Braun',
#        'link': '/api/v1/people/460075'},
#       'coordinates': {'x': 178.9, 'y': 129.87},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 519058,
#        'fullName': 'Mike Moustakas',
#        'link': '/api/v1/people/519058'},
#       'coordinates': {'x': 188.8, 'y': 34.85},
#       'type': 'H',
#       'description': 'Home Run'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 571927,
#        'fullName': 'Steven Matz',
#        'link': '/api/v1/people/571927'},
#       'batter': {'id': 541650,
#        'fullName': 'Hernan Perez',
#        'link': '/api/v1/people/541650'},
#       'coordinates': {'x': 162.52, 'y': 56.48},
#       'type': 'O',
#       'description': 'Flyout'}],
#     'home': [{'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 606930,
#        'fullName': 'Jacob Barnes',
#        'link': '/api/v1/people/606930'},
#       'batter': {'id': 642708,
#        'fullName': 'Amed Rosario',
#        'link': '/api/v1/people/642708'},
#       'coordinates': {'x': 170.81, 'y': 66.02},
#       'type': 'E',
#       'description': 'Field Error'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 592222,
#        'fullName': 'Alex Claudio',
#        'link': '/api/v1/people/592222'},
#       'batter': {'id': 605204,
#        'fullName': 'J.D. Davis',
#        'link': '/api/v1/people/605204'},
#       'coordinates': {'x': 101.11, 'y': 138.63},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 7,
#       'pitcher': {'id': 658792,
#        'fullName': 'Aaron Wilkerson',
#        'link': '/api/v1/people/658792'},
#       'batter': {'id': 501571,
#        'fullName': 'Juan Lagares',
#        'link': '/api/v1/people/501571'},
#       'coordinates': {'x': 132.17, 'y': 174.06},
#       'type': 'O',
#       'description': 'Groundout'}]}},
#   {'startIndex': 54,
#    'endIndex': 63,
#    'top': [54, 55, 56],
#    'bottom': [57, 58, 59, 60, 61, 62, 63],
#    'hits': {'away': [],
#     'home': [{'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 658792,
#        'fullName': 'Aaron Wilkerson',
#        'link': '/api/v1/people/658792'},
#       'batter': {'id': 453943,
#        'fullName': 'Todd Frazier',
#        'link': '/api/v1/people/453943'},
#       'coordinates': {'x': 45.81, 'y': 95.33},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 658792,
#        'fullName': 'Aaron Wilkerson',
#        'link': '/api/v1/people/658792'},
#       'batter': {'id': 467092,
#        'fullName': 'Wilson Ramos',
#        'link': '/api/v1/people/467092'},
#       'coordinates': {'x': 86.44982569721115, 'y': 114.63147281175591},
#       'type': 'H',
#       'description': 'Single'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 658792,
#        'fullName': 'Aaron Wilkerson',
#        'link': '/api/v1/people/658792'},
#       'batter': {'id': 642708,
#        'fullName': 'Amed Rosario',
#        'link': '/api/v1/people/642708'},
#       'coordinates': {'x': 180.4, 'y': 113.84},
#       'type': 'O',
#       'description': 'Flyout'},
#      {'team': {'id': 121,
#        'name': 'New York Mets',
#        'link': '/api/v1/teams/121',
#        'springLeague': {'id': 115,
#         'name': 'Grapefruit League',
#         'link': '/api/v1/league/115',
#         'abbreviation': 'GL'},
#        'allStarStatus': 'N'},
#       'inning': 8,
#       'pitcher': {'id': 658792,
#        'fullName': 'Aaron Wilkerson',
#        'link': '/api/v1/people/658792'},
#       'batter': {'id': 621512,
#        'fullName': 'Tomas Nido',
#        'link': '/api/v1/people/621512'},
#       'coordinates': {'x': 199.75, 'y': 121.54},
#       'type': 'H',
#       'description': 'Double'}]}},
#   {'startIndex': 64,
#    'endIndex': 66,
#    'top': [64, 65, 66],
#    'bottom': [],
#    'hits': {'away': [{'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 621242,
#        'fullName': 'Edwin Diaz',
#        'link': '/api/v1/people/621242'},
#       'batter': {'id': 456715,
#        'fullName': 'Lorenzo Cain',
#        'link': '/api/v1/people/456715'},
#       'coordinates': {'x': 135.13, 'y': 159.51},
#       'type': 'O',
#       'description': 'Groundout'},
#      {'team': {'id': 158,
#        'name': 'Milwaukee Brewers',
#        'link': '/api/v1/teams/158',
#        'springLeague': {'id': 114,
#         'name': 'Cactus League',
#         'link': '/api/v1/league/114',
#         'abbreviation': 'CL'},
#        'allStarStatus': 'N'},
#       'inning': 9,
#       'pitcher': {'id': 621242,
#        'fullName': 'Edwin Diaz',
#        'link': '/api/v1/people/621242'},
#       'batter': {'id': 460075,
#        'fullName': 'Ryan Braun',
#        'link': '/api/v1/people/460075'},
#       'coordinates': {'x': 128.25, 'y': 143.44},
#       'type': 'O',
#       'description': 'Lineout'}],
#     'home': []}}]}

# %%
may_gamepks = list(range(566000, 566110))
len(may_gamepks)
# Out:
# 110

# %%
gampks_2019 = list(range(565799, 566110))
len(gampks_2019)
# Out:
# 311

# %%
schedule = statsapi.schedule(start_date="05/01/2019", end_date="05/26/2019")

# %%
from pandas.io.json import json_normalize

# %%
full = json_normalize(schedule)

# %%
df = json_normalize(schedule)['game_id']

# %%
mariners_game = statsapi.schedule(start_date="05/01/2019", end_date="05/05/2019", team=136)
mariners_game
# Out:
# [{'game_id': 566389,
#   'game_datetime': '2019-05-01T22:40:00Z',
#   'game_date': '2019-05-01',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Chicago Cubs',
#   'home_name': 'Seattle Mariners',
#   'away_id': 112,
#   'home_id': 136,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Gonzales, Marco',
#   'away_probable_pitcher': 'Lester, Jon',
#   'home_pitcher_note': 'Gonzales is 6-0 with a 2.45 ERA in 11 starts since last September. He threw 7 scoreless innings with 9 strikeouts his last outing vs. Texas. He beat the Cubs in his only previous meeting as a Cardinals rookie in 2014 with 6 innings of one-run ball.',
#   'away_pitcher_note': 'Lester is set to make his second start since coming off the injured list on Thursday, when he held the Dodgers to a run on four hits while striking out five in five innings but took the loss because the Cubs were shut out until the ninth.',
#   'away_score': 11,
#   'home_score': 0,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'winning_team': 'Chicago Cubs',
#   'losing_team': 'Seattle Mariners',
#   'winning_pitcher': 'Jon Lester',
#   'losing_pitcher': 'Marco Gonzales',
#   'save_pitcher': None,
#   'summary': '2019-05-01 - Chicago Cubs (11) @ Seattle Mariners (0) (Final)'},
#  {'game_id': 565327,
#   'game_datetime': '2019-05-03T23:10:00Z',
#   'game_date': '2019-05-03',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Seattle Mariners',
#   'home_name': 'Cleveland Indians',
#   'away_id': 136,
#   'home_id': 114,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Bieber, Shane',
#   'away_probable_pitcher': 'Kikuchi, Yusei',
#   'home_pitcher_note': 'Bieber opens the homestand looking to improve upon his 6.12 career ERA at Progressive Field. He allowed one run on four hits over six-plus innings in an April 16 win vs. the Mariners. He struck out five and walked three, recording 12 fly ball outs.',
#   'away_pitcher_note': 'Kikuchi threw one perfect inning in his last start as the Mariners look to limit his workload, but he’ll now be back to normal duty. He picked up his first MLB win in his previous outing in Anaheim, though he held the lead in four prior no-decisions.',
#   'away_score': 1,
#   'home_score': 2,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'winning_team': 'Cleveland Indians',
#   'losing_team': 'Seattle Mariners',
#   'winning_pitcher': 'Brad Hand',
#   'losing_pitcher': 'Anthony Swarzak',
#   'save_pitcher': None,
#   'summary': '2019-05-03 - Seattle Mariners (1) @ Cleveland Indians (2) (Final)'},
#  {'game_id': 565328,
#   'game_datetime': '2019-05-04T20:10:00Z',
#   'game_date': '2019-05-04',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Seattle Mariners',
#   'home_name': 'Cleveland Indians',
#   'away_id': 136,
#   'home_id': 114,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Carrasco, Carlos',
#   'away_probable_pitcher': 'Leake, Mike',
#   'home_pitcher_note': "Carrasco's last win came against the Mariners on April 17 in Seattle. He scattered three hits over seven scoreless innings, with 12 strikeouts and two walks. Carrasco threw a season-high 108 pitches.",
#   'away_pitcher_note': 'Since starting the year with two wins, Leake has gone 0-3 with a 6.14 ERA and eight home runs allowed in four starts. His best outing in that stretch was against the Indians, allowing eight hits and two runs in six innings in a 4-2 loss in Seattle on April 16.',
#   'away_score': 4,
#   'home_score': 5,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'winning_team': 'Cleveland Indians',
#   'losing_team': 'Seattle Mariners',
#   'winning_pitcher': 'Tyler Olson',
#   'losing_pitcher': 'Connor Sadzeck',
#   'save_pitcher': 'Brad Hand',
#   'summary': '2019-05-04 - Seattle Mariners (4) @ Cleveland Indians (5) (Final)'},
#  {'game_id': 565329,
#   'game_datetime': '2019-05-05T17:10:00Z',
#   'game_date': '2019-05-05',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Seattle Mariners',
#   'home_name': 'Cleveland Indians',
#   'away_id': 136,
#   'home_id': 114,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Anderson, Cody',
#   'away_probable_pitcher': 'Swanson, Erik',
#   'home_pitcher_note': "With Mike Clevinger and Corey Kluber on the injured list, Anderson will make his first big league start since Sept. 24, 2016. He missed the last two seasons after Tommy John surgery, returning on April 13. He's posted a 5.40 ERA in five innings of relief.",
#   'away_pitcher_note': 'The 25-year-old rookie makes his fourth start in place of the injured Wade LeBlanc, still looking for his first win. His best outing came in his starting debut vs. the Indians, allowing two hits and one run in six innings in a 1-0 loss in Seattle.',
#   'away_score': 10,
#   'home_score': 0,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'winning_team': 'Seattle Mariners',
#   'losing_team': 'Cleveland Indians',
#   'winning_pitcher': 'Erik Swanson',
#   'losing_pitcher': 'Cody Anderson',
#   'save_pitcher': None,
#   'summary': '2019-05-05 - Seattle Mariners (10) @ Cleveland Indians (0) (Final)'}]

# %%
full['game_id'].value_counts()
full.loc[full['game_id'] == 566590]
# Out:
#      away_id           away_name  \
# 279      118  Kansas City Royals
# 284      118  Kansas City Royals
#
#                                      away_pitcher_note away_probable_pitcher  \
# 279                                                            Bailey, Homer
# 284  Bailey's previous start vs. the Rangers began ...         Bailey, Homer
#
#     away_score current_inning doubleheader   game_date         game_datetime  \
# 279          0                           N  2019-05-21  2019-05-22T00:15:00Z
# 284          3              9            S  2019-05-22  2019-05-22T23:45:00Z
#
#      game_id         ...           home_probable_pitcher home_score  \
# 279   566590         ...                  Wacha, Michael          0
# 284   566590         ...                Wainwright, Adam         10
#
#      inning_state losing_pitcher         losing_team save_pitcher     status  \
# 279                          NaN                 NaN          NaN  Postponed
# 284           Top   Homer Bailey  Kansas City Royals         None      Final
#
#                                                summary  winning_pitcher  \
# 279  2019-05-21 - Kansas City Royals @ St. Louis Ca...              NaN
# 284  2019-05-22 - Kansas City Royals (3) @ St. Loui...  Adam Wainwright
#
#             winning_team
# 279                  NaN
# 284  St. Louis Cardinals
#
# [2 rows x 25 columns]

# %%
len(df.unique())
# Out:
# 351

# %%
game = statsapi.get('game_playByPlay',{"gamePk":565997})

# %%
type(game)
# Out:
# dict

# %%
game.keys()
# Out:
# dict_keys(['copyright', 'allPlays', 'currentPlay', 'scoringPlays', 'playsByInning'])

# %%
plays = game['allPlays']

# %%
df = pd.DataFrame(plays)
df.head(2)
# Out:
#                                                about actionIndex  atBatIndex  \
# 0  {'atBatIndex': 0, 'halfInning': 'top', 'inning...          []           0
# 1  {'atBatIndex': 1, 'halfInning': 'top', 'inning...          []           1
#
#                                    count  \
# 0  {'balls': 3, 'strikes': 3, 'outs': 1}
# 1  {'balls': 2, 'strikes': 2, 'outs': 1}
#
#                                              matchup  \
# 0  {'batter': {'id': 457705, 'fullName': 'Andrew ...
# 1  {'batter': {'id': 592663, 'fullName': 'J.T. Re...
#
#                  pitchIndex               playEndTime  \
# 0        [0, 1, 2, 3, 4, 5]  2019-04-24T23:13:04.000Z
# 1  [0, 1, 2, 3, 4, 5, 6, 7]  2019-04-24T23:15:53.000Z
#
#                                           playEvents  \
# 0  [{'details': {'call': {'code': 'B', 'descripti...
# 1  [{'details': {'call': {'code': 'S', 'descripti...
#
#                                               result runnerIndex  \
# 0  {'type': 'atBat', 'event': 'Strikeout', 'event...         [0]
# 1  {'type': 'atBat', 'event': 'Double', 'eventTyp...         [0]
#
#                                              runners
# 0  [{'movement': {'start': None, 'end': None, 'ou...
# 1  [{'movement': {'start': None, 'end': '2B', 'ou...
